# %%
import pandas as pd
import re
# Lee el archivo Excel
df = pd.read_excel('Grid1.xlsx')
# Borra columnas vacias
# df.drop(columns=['acknowledgment_number', 'acknowledgment_total'], inplace=True)
# Asigna NAMELESS a vendor-name vacio
df['vendor_name'] = df['vendor_name'].fillna('NAMELESS')
# Convierte a mayusculas
df['vendor_name']  = df['vendor_name'].str.upper()
# Ignora caracteres especiales
df['vendor_name']  = df['vendor_name'].str.replace('. ', '')
df['vendor_name']  = df['vendor_name'].str.replace('.', '')
df['vendor_name']  = df['vendor_name'].str.replace(':', '')
df['vendor_name']  = df['vendor_name'].str.replace('•', '')
df['vendor_name']  = df['vendor_name'].str.replace('[', '')
df['vendor_name']  = df['vendor_name'].str.replace('`', '')
df['vendor_name']  = df['vendor_name'].str.replace(',,', '')
df['vendor_name']  = df['vendor_name'].str.replace('_', '')
df['vendor_name']  = df['vendor_name'].str.replace('+', '')
df['vendor_name']  = df['vendor_name'].str.replace('=', '')
df['vendor_name']  = df['vendor_name'].str.replace('*', '')
df['vendor_name']  = df['vendor_name'].str.replace('¡', '')
df['vendor_name']  = df['vendor_name'].str.replace('!-', '')
df['vendor_name']  = df['vendor_name'].str.replace('/', '_')
df['vendor_name'] = df['vendor_name'].str.strip()

# Ordenamos el dataset por 'countriesAndTerritories' & 'dateRep'
df = df.sort_values(by=['vendor_name'], ignore_index=True)

# Crea dfVendor
dfVendor = pd.DataFrame(df['vendor_name'])
# Elimina Duplicados
dfVendor = dfVendor.drop_duplicates()

# Crea libro Excel
with pd.ExcelWriter('datos_separados_por_proveedor.xlsx') as writer:
    for index, row in dfVendor.iterrows():
        df.query("vendor_name==@row['vendor_name']").to_excel(writer, sheet_name=row['vendor_name'], index=False)
        print(row['vendor_name'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 39
#      37 with pd.ExcelWriter('datos_separados_por_proveedor.xlsx') as writer:
#      38     for index, row in dfVendor.iterrows():
# ---> 39         df.query("vendor_name==@row['vendor_name']").to_excel(writer, sheet_name=row['vendor_name'], index=False)
#      40         print(row['vendor_name'])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4450, in DataFrame.query(self, expr, inplace, **kwargs)
#    4448 kwargs["level"] = kwargs.pop("level", 0) + 1
#    4449 kwargs["target"] = None
# -> 4450 res = self.eval(expr, **kwargs)
#    4452 try:
#    4453     result = self.loc[res]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4576, in DataFrame.eval(self, expr, inplace, **kwargs)
#    4573     kwargs["target"] = self
#    4574 kwargs["resolvers"] = tuple(kwargs.get("resolvers", ())) + resolvers
# -> 4576 return _eval(expr, inplace=inplace, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\eval.py:336, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     327 # get our (possibly passed-in) scope
#     328 env = ensure_scope(
#     329     level + 1,
#     330     global_dict=global_dict,
#    (...)
#     333     target=target,
#     334 )
# --> 336 parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#     338 if engine == "numexpr" and (
#     339     is_extension_array_dtype(parsed_expr.terms.return_type)
#     340     or getattr(parsed_expr.terms, "operand_types", None) is not None
#    (...)
#     344     )
#     345 ):
#     346     warnings.warn(
#     347         "Engine has switched to 'python' because numexpr does not support "
#     348         "extension array dtypes. Please set your engine to python manually.",
#     349         RuntimeWarning,
#     350         stacklevel=find_stack_level(),
#     351     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:809, in Expr.__init__(self, expr, engine, parser, env, level)
#     807 self.parser = parser
#     808 self._visitor = PARSERS[parser](self.env, self.engine, self.parser)
# --> 809 self.terms = self.parse()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:828, in Expr.parse(self)
#     824 def parse(self):
#     825     """
#     826     Parse an expression.
#     827     """
# --> 828     return self._visitor.visit(self.expr)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:421, in BaseExprVisitor.visit_Module(self, node, **kwargs)
#     419     raise SyntaxError("only a single expression is allowed")
#     420 expr = node.body[0]
# --> 421 return self.visit(expr, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:424, in BaseExprVisitor.visit_Expr(self, node, **kwargs)
#     423 def visit_Expr(self, node, **kwargs):
# --> 424     return self.visit(node.value, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:719, in BaseExprVisitor.visit_Compare(self, node, **kwargs)
#     717     op = self.translate_In(ops[0])
#     718     binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 719     return self.visit(binop)
#     721 # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#     722 left = node.left
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:535, in BaseExprVisitor.visit_BinOp(self, node, **kwargs)
#     534 def visit_BinOp(self, node, **kwargs):
# --> 535     op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     536     left, right = self._maybe_downcast_constants(left, right)
#     537     return self._maybe_evaluate_binop(op, op_class, left, right)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:457, in BaseExprVisitor._maybe_transform_eq_ne(self, node, left, right)
#     455     left = self.visit(node.left, side="left")
#     456 if right is None:
# --> 457     right = self.visit(node.right, side="right")
#     458 op, op_class, left, right = self._rewrite_membership_op(node, left, right)
#     459 return op, op_class, left, right
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:415, in BaseExprVisitor.visit(self, node, **kwargs)
#     413 method = f"visit_{type(node).__name__}"
#     414 visitor = getattr(self, method)
# --> 415 return visitor(node, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\expr.py:578, in BaseExprVisitor.visit_Subscript(self, node, **kwargs)
#     576 value = self.visit(node.value)
#     577 slobj = self.visit(node.slice)
# --> 578 result = pd_eval(
#     579     slobj, local_dict=self.env, engine=self.engine, parser=self.parser
#     580 )
#     581 try:
#     582     # a Term instance
#     583     v = value.value[result]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\eval.py:357, in eval(expr, parser, engine, local_dict, global_dict, resolvers, level, target, inplace)
#     355 eng = ENGINES[engine]
#     356 eng_inst = eng(parsed_expr)
# --> 357 ret = eng_inst.evaluate()
#     359 if parsed_expr.assigner is None:
#     360     if multi_line:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\engines.py:81, in AbstractEngine.evaluate(self)
#      78     self.result_type, self.aligned_axes = align_terms(self.expr.terms)
#      80 # make sure no names in resolvers and locals/globals clash
# ---> 81 res = self._evaluate()
#      82 return reconstruct_object(
#      83     self.result_type, res, self.aligned_axes, self.expr.terms.return_type
#      84 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\computation\engines.py:121, in NumExprEngine._evaluate(self)
#     119 scope = env.full_scope
#     120 _check_ne_builtin_clash(self.expr)
# --> 121 return ne.evaluate(s, local_dict=scope)
#
# File ~\anaconda3\Lib\site-packages\numexpr\necompiler.py:835, in evaluate(ex, local_dict, global_dict, out, order, casting, **kwargs)
#     833 _numexpr_last = dict(ex=compiled_ex, argnames=names, kwargs=kwargs)
#     834 with evaluate_lock:
# --> 835     return compiled_ex(*arguments, **kwargs)
#
# ValueError: data type must provide an itemsize
